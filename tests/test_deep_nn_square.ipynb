# %%
import numba
import sys
sys.path.insert(0, '../python_lib')
import networkx as nx
import numpy as np
import graph_gen
import model
import random
from collections import defaultdict
import torch
import math
import solvers
import imp

# %%
# %matplotlib inline

# %% [markdown]
# # Spin system on tree network
#
# ### inter_H -> random external fields
#
# ### j_start -> values of ferromagnet interactions
#
# We generate a tree:
# 1. ordered from a root
# 2. non-ordered (the same nodes are swapped)

# %%
m = n = l = 16 # L of square grid

# %%
import imp 

import graph_gen
imp.reload(graph_gen)
periodic = False
N, J_interaction = graph_gen.grid_2d_interaction(n,m, periodic=periodic)

#H = np.random.random(N)
H=np.zeros(N)

inter_H = 4
H = inter_H * (2.* np.random.random(N) - 1)
H = np.zeros(N)

betas = [0.5]

j_start = 1
j = graph_gen.fixed_value(j_start)
J = graph_gen.set_J(J_interaction, j)
#N_rand, J_interaction_rand = graph_gen.tree_interaction(Degree, Height, rand=True)

# %% [markdown]
# # Exact solutions
# enumerating all configurations.

# %%
import model
imp.reload(model)
tree = model.model(N, H, J, J_interaction)

# %%
beta = betas[0]
tree.exact(beta)
# Out:
# beta: 0.5, Fe: -2.138 Energy: -1.76 M: 0.0 S: 0.191-33.19
# -34.210734237464486

# %%
import bp_solver
bp_sol = bp_solver.BP_solver(tree)
bp_sol.converge(beta,val_rand=0.9,)
# Out:
# fe: -1.958, ener: -1.541, M: 0.860, iter 49

# %% [markdown]
# # Neural network solutions
# bp case

# %%
import bp_nn
imp.reload(bp_nn)
bias = True
net = bp_nn.bp_nn(tree.N, tree, bias, z2=False)
net.train(beta=beta, 
          lr=0.01, 
        batch_size=1000,
        max_step=1000,
         std_fe_limit=0.00001, 
)
net.compute_stat_is(beta, batch_size=10000)
# Out:
#  0.50 1000 fe: -1.958 +- 0.01103 E: -1.528, S: 0.215, M: 0.825, B1 = -0.890
# free_energy: -1.967,  std_fe: 0.00133, mag_mean: 0.781, entropy: 0.239 energy: -1.490
# tensor(-1.9672, dtype=torch.float64)

# %%
import matplotlib.pyplot as plt
plt.plot(net.M_i,tree.M_i_mean , 'bo')

# %%
tree_c = tree.Corr_neigh.flatten()
nn_c = net.Corr_neigh.numpy().flatten()
tree_c = tree_c[tree_c != 0]
nn_c = nn_c[nn_c != 0]

# %%
import matplotlib.pyplot as plt

plt.plot(tree_c, nn_c , 'bo');

# %%
tree_c = tree.Corr.flatten()
nn_c = net.Corr.numpy().flatten()
tree_c = tree_c[tree_c != 0]
nn_c = nn_c[nn_c != 0]

# %%
import matplotlib.pyplot as plt

plt.plot(tree_c, nn_c , 'bo');

# %% [markdown]
# # NN deep no deep

# %%
import bp_nn_deep
imp.reload(bp_nn_deep)

neighs = bp_nn_deep.find_neigh(tree)
neighs = bp_nn_deep.find_neigh_neigh(tree)
neighs = bp_nn_deep.find_neigh_plaq(tree)
# Out:
# 256 16.0

# %%
import bp_nn_deep
imp.reload(bp_nn_deep)

neighs = bp_nn_deep.find_neigh(tree)
neighs = bp_nn_deep.find_neigh_neigh(tree)
ne
in_out_layers = []
for n_i in range(tree.N):
    in_ = len(neighs[n_i]) if len(neighs[n_i]) else 1
    lay = [in_, in_+10, in_]
    lay.append(1)
    in_out_layers.append(lay)

# %%
in_out_layers
# Out:
# [[1, 11, 1, 1],
#  [1, 11, 1, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [2, 12, 2, 1],
#  [1, 11, 1, 1],
#  [3, 13, 3, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [4, 14, 4, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [2, 12, 2, 1],
#  [4, 14, 4, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1],
#  [5, 15, 5, 1]]

# %%
import bp_nn_deep
imp.reload(bp_nn_deep)
bias = True

net = bp_nn_deep.bp_nn_deep(tree, bias, in_out_layers, neighs)

# %%
import bp_nn_deep
imp.reload(bp_nn_deep)
bias = True

net.train(beta=beta, 
          lr=0.01,  
        batch_size=1000,
      max_step=2000,
         std_fe_limit=0.00001, 
)
net.compute_stat_is(beta, batch_size=10000)
# Out:
#  0.50 174 fe: -1.911 +- 0.02974 E: -1.492, S: 0.209, M: 0.828
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-89-497f54b91fbb> in <module>
#       7         batch_size=1000,
#       8       max_step=2000,
# ----> 9          std_fe_limit=0.00001,
#      10 )
#      11 net.compute_stat_is(beta, batch_size=10000)
#
# ~/git/pytorch_test/python_lib/bp_nn_deep.py in train(self, lr, opt, beta, max_step, batch_size, std_fe_limit, batch_mean, random_update, random_zero)
#     356             assert not loss.requires_grad
#     357             loss_reinforce = torch.mean((loss - loss.mean()) * log_prob)
# --> 358             loss_reinforce.backward()
#     359             if random_update:
#     360                 self.rand_grad(prob_zero = random_zero)
#
# /usr/local/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     148                 products. Defaults to ``False``.
#     149         """
# --> 150         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     151
#     152     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
import bp_nn_deep
imp.reload(bp_nn_deep)

net.train(beta=beta, 
          lr=0.001, 
        batch_size=10000,
      max_step=2000,
         std_fe_limit=0.00001, 
)
net.compute_stat_is(beta, batch_size=10000)
# Out:
#  0.50 108 fe: -2.132 +- 0.02302 E: -1.786, S: 0.173, M: 0.00991
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-167105581252> in <module>
#       7         batch_size=10000,
#       8       max_step=2000,
# ----> 9          std_fe_limit=0.00001,
#      10 )
#      11 net.compute_stat_is(beta, batch_size=10000)
#
# ~/git/pytorch_test/python_lib/bp_nn_deep.py in train(self, lr, opt, beta, max_step, batch_size, std_fe_limit, batch_mean, random_update, random_zero)
#     356             assert not loss.requires_grad
#     357             loss_reinforce = torch.mean((loss - loss.mean()) * log_prob)
# --> 358             loss_reinforce.backward()
#     359             if random_update:
#     360                 self.rand_grad(prob_zero = random_zero)
#
# /usr/local/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     148                 products. Defaults to ``False``.
#     149         """
# --> 150         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     151
#     152     def register_hook(self, hook):
#
# /usr/local/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
import matplotlib.pyplot as plt
plt.plot(net.M_i,tree.M_i_mean , 'bo')

# %%
tree_c = tree.Corr.flatten()
nn_c = net.Corr.numpy().flatten()
tree_c = tree_c[tree_c != 0]
nn_c = nn_c[nn_c != 0]

# %%
import matplotlib.pyplot as plt

plt.plot(tree_c, nn_c , 'bo');

# %% [markdown]
# ## random case

# %%
import bp_nn
imp.reload(bp_nn)

net_rand = bp_nn.bp_nn(tree_rand.N, tree_rand, True, z2=False, init_zero=False,)
                      
net_rand.train(beta=beta, lr=0.01, 
           max_step=10000,
               opt="adam")
# Out:
#  0.20 10000 fe: -3.558 +- 0.01314 E: -0.192, S: 0.673, M: 0.0269, B1 = 0.002
# {'free_energy_mean': tensor(-3.5585, dtype=torch.float64),
#  'free_energy_std': tensor(0.0131, dtype=torch.float64),
#  'entropy_mean': tensor(0.6733, dtype=torch.float64, grad_fn=<DivBackward0>),
#  'energy_mean': tensor(-0.1919, dtype=torch.float64),
#  'mag': tensor([ 0.0380, -0.0280,  0.0220, -0.0200,  0.0200, -0.0240,  0.0120, -0.0320,
#           0.0120,  0.0120,  0.0680, -0.0560, -0.0220,  0.0140,  0.0240]),
#  'mag_mean': tensor(0.0269)}

# %%
net_rand.compute_stat_is(beta, batch_size=10000)
# Out:
# free_energy: -3.558,  std_fe: 0.00001, mag_mean: 0.008, entropy: 0.675 energy: -0.184
# tensor(-3.5584, dtype=torch.float64)

# %% [markdown]
# ## random case with deep

# %%
import bp_nn_deep
imp.reload(bp_nn_deep)

neighs = bp_nn_deep.find_neigh(tree)
in_out_layers = []
for n_i in range(tree.N):
    in_ = len(neighs[n_i]) if len(neighs[n_i]) else 1
    in_out_layers.append([in_, 1])

# %% [markdown]
# # Large networks BP solution

# %%
Degree = 3 # degree
Height = 6 # Height of the tree

# %%
import imp 

import graph_gen
imp.reload(graph_gen)
N, J_interaction = graph_gen.tree_interaction(Degree,Height)

inter_H = 4
H = inter_H * (2.* np.random.random(N) - 1)
#H = np.zeros(N)

num_swap = 3
J_interaction_rand, H_rand = graph_gen.order_rand(N, 
                                                  J_interaction, 
                                                  H, num_swap=num_swap)

graph_gen.plot_matrix_graph(J_interaction_rand)

betas = np.arange(1e-6,2,1e-2)
betas_fast = np.arange(0.1,2,4e-1)

j_start = 1
j = graph_gen.fixed_value(j_start)
J = graph_gen.set_J(J_interaction, j)
J_rand = graph_gen.set_J(J_interaction_rand, j)

#N_rand, J_interaction_rand = graph_gen.tree_interaction(Degree, Height, rand=True)
# Out:
# [[35, 37], [123, 18], [108, 79]]

# %%
import model
imp.reload(model)
tree = model.model(N, H, J, J_interaction)
tree_rand = model.model(N, H_rand, J_rand, J_interaction_rand)

# %%
import bp_solver
bp_sol = bp_solver.BP_solver(tree)
beta = 0.2

# %%
bp_sol.converge(beta)
# Out:
# fe: -4.043, ener: -1.082, M: 0.364, iter 8

# %%
bp_sol.free_energy(beta)
# Out:
# -4.043164119293446

# %%
import bp_nn
imp.reload(bp_nn)
bias = True
net = bp_nn.bp_nn(tree.N, tree, bias, z2=False)
net.train(beta=beta, 
          lr=0.01, 
        batch_size=1000,
         std_fe_limit=0.00001, 
)
net.compute_stat_is(beta, batch_size=10000)
# Out:
#  0.20 2050 fe: -4.043 +- 0.00001 E: -1.089, S: 0.591, M: 0.366, B1 = 1.228
# free_energy: -4.043,  std_fe: 0.00000, mag_mean: 0.364, entropy: 0.592 energy: -1.084
# tensor(-4.0432, dtype=torch.float64)

# %%
net.compute_stat_is(beta, batch_size=10000)
# Out:
# free_energy: -4.043,  std_fe: 0.00000, mag_mean: 0.363, entropy: 0.592 energy: -1.082
# tensor(-4.0432, dtype=torch.float64)

# %%
import matplotlib.pyplot as plt
plt.plot(net.M_i,bp_sol.M_i , 'bo')

# %%
tree_c = bp_sol.Corr_neigh.flatten()
nn_c = net.Corr_neigh.numpy().flatten()
tree_c = tree_c[tree_c != 0]
nn_c = nn_c[nn_c != 0]

# %%
import matplotlib.pyplot as plt

plt.plot(tree_c, nn_c , 'bo');

# %%
# deep

# %%
import bp_nn_deep
imp.reload(bp_nn_deep)

neighs = bp_nn_deep.find_neigh(tree)
in_out_layers = []
for n_i in range(tree.N):
    in_ = len(neighs[n_i]) if len(neighs[n_i]) else 1
    in_out_layers.append([in_, 1])

# %%
import bp_nn_more
imp.reload(bp_nn_deep)
bias = True

net = bp_nn_deep.bp_nn_deep(tree, bias, in_out_layers, neighs)
net.train(beta=beta, 
          lr=0.01, 
        batch_size=1000,
         std_fe_limit=0.00001, 
)
net.compute_stat_is(beta, batch_size=10000)
# Out:
#  0.20 9 fe: -3.250 +- 0.24771 E: -0.130, S: 0.624, M: 0.258
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-259-e9cee91f5f82> in <module>
#       7           lr=0.01,
#       8         batch_size=1000,
# ----> 9          std_fe_limit=0.00001,
#      10 )
#      11 net.compute_stat_is(beta, batch_size=10000)
#
# ~/git/pytorch_test/python_lib/bp_nn_deep.py in train(self, lr, opt, beta, max_step, batch_size, std_fe_limit, batch_mean, random_update, random_zero)
#     319             optimizer.zero_grad()
#     320             with torch.no_grad():
# --> 321                 sample, x_hat = self.sample(batch_size)
#     322             assert not sample.requires_grad
#     323             assert not x_hat.requires_grad
#
# ~/git/pytorch_test/python_lib/bp_nn_deep.py in sample(self, batch_size)
#     112             [batch_size, self.n])
#     113         for i in range(self.n):
# --> 114             x_hat = self.forward(sample)
#     115             #print(x_hat)
#     116             sample[:, i] = torch.bernoulli(
#
# ~/git/pytorch_test/python_lib/bp_nn_deep.py in forward(self, x)
#      67
#      68             #print(input_x, self.nn_one[n])
# ---> 69             x_hat[:,n_i] = self.nn_one[n_i](input_x).t()
#      70
#      71         return x_hat
#
# KeyboardInterrupt:
