# %%
import numba
import sys
sys.path.insert(0, '../../../python_lib')
import networkx as nx
import numpy as np
import graph_gen
import model
import random
from collections import defaultdict
import torch
import math
import solvers

# %%
# %matplotlib inline

# %%
f_j = open("RRG_J.txt")
J = []
with open('RRG_J.txt') as f:
    for row_s in f.readlines():
        row  = [float(x) for x in row_s.split()]
        J.append(row)

# %%
import matplotlib.pyplot as plt
from networkx.drawing.nx_agraph import graphviz_layout

J = np.array(J)
G=nx.from_numpy_matrix(J)
pos = graphviz_layout(G, args='')
plt.figure(figsize=(8, 8))
nx.draw(G, pos, node_size=50)
plt.axis('equal')
plt.show()

# %%
J_interaction = (J!=0).astype(int)

# %%
J.shape[0]
# Out:
# 1100

# %%
import imp 
N = J.shape[0]
H = np.zeros(N)
#J_interaction = graph_gen.reorder_graph(J_interaction, 
#                                        root = 0)
#H = np.random.random(N)
betas_fast = [0.9]

# %%
tree = model.model(N, H, J, J_interaction)

# %%
import solvers
imp.reload(solvers)
res_ex = solvers.exact_sol(tree, betas_fast)
# Out:
# beta: 0.1, Fe: -7.033 Energy: -0.206 M: 0.0 S: 0.683-1.12e+02
# beta: 0.2, Fe: -3.679 Energy: -0.456 M: 0.0 S: 0.644-58.6
# beta: 0.3, Fe: -2.664 Energy: -0.844 M: 0.0 S: 0.54642.17
# beta: 0.4, Fe: -2.275 Energy: -1.38 M: 3.45e-18 S: 0.3588
# beta: 0.5, Fe: -2.138 Energy: -1.76 M: 0.0 S: 0.191 -33.1
# beta: 0.6, Fe: -2.089 Energy: -1.91 M: 8.14e-15 S: 0.1094
# beta: 0.7, Fe: -2.068 Energy: -1.96 M: 0.0 S: 0.0731-32.1
# beta: 0.8, Fe: -2.056 Energy: -1.98 M: 0.0 S: 0.0573-32.1
# beta: 0.9, Fe: -2.049 Energy: -1.99 M: 0.0 S: 0.05= -32.0
# beta: 1.0, Fe: -2.044 Energy: -2.0 M: 0.0 S: 0.0465 -32.0
# beta: 1.1, Fe: -2.040 Energy: -2.0 M: 0.0 S: 0.0449 -32.0
# beta: 1.2, Fe: -2.036 Energy: -2.0 M: 0.0 S: 0.0441 -32.0
# beta: 1.3, Fe: -2.033 Energy: -2.0 M: 0.0 S: 0.0437 -32.0
# beta: 1.4, Fe: -2.031 Energy: -2.0 M: 0.0 S: 0.0435 -32.0
# beta: 1.5, Fe: -2.029 Energy: -2.0 M: 0.0 S: 0.0434 -32.0
# beta: 1.6, Fe: -2.027 Energy: -2.0 M: 0.0 S: 0.0434 -32.0
# beta: 1.7, Fe: -2.025 Energy: -2.0 M: 0.0 S: 0.0433 -32.0
# beta: 1.8, Fe: -2.024 Energy: -2.0 M: 0.0 S: 0.0433 -32.0
# beta: 1.9, Fe: -2.023 Energy: -2.0 M: 0.0 S: 0.0433 -32.0
# beta: 2.0, Fe: -2.022 Energy: -2.0 M: 0.0 S: 0.0433 -32.0

# %%
import solvers
imp.reload(solvers)

res_nn = solvers.nn_sol(tree, betas_fast, max_step=1000, bias = True, 
                        z2 = False, x_hat_clip = False)
res_nn["name"]="nn"
# Out:
#  0.90 91 fe: -0.758 +- 0.03689 E: -0.035, S: 0.651, M: 0.175, B1 = -0.515
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-55-1b21206304d1> in <module>
#       3
#       4 res_nn = solvers.nn_sol(tree, betas_fast, max_step=1000, bias = True,
# ----> 5                         z2 = False, x_hat_clip = False)
#       6 res_nn["name"]="nn"
#
# ~/git/pytorch_test/python_lib/solvers.py in nn_sol(model, betas, bias, z2, x_hat_clip, stats, lr, max_step, batch_size, opt, nn_use, init_net, i_sampling)
#      57         net.train(beta = beta, lr=lr, max_step=max_step,
#      58                   batch_size=batch_size,
# ---> 59                  opt = opt)
#      60         F = +1e100
#      61         E = 0
#
# ~/git/pytorch_test/python_lib/bp_nn.py in train(self, lr, opt, beta, max_step, batch_size, std_fe_limit, batch_mean, x_hat_clip, random_update, random_zero)
#     391             optimizer.zero_grad()
#     392             with torch.no_grad():
# --> 393                 sample, x_hat = self.sample(batch_size)
#     394             assert not sample.requires_grad
#     395             assert not x_hat.requires_grad
#
# ~/git/pytorch_test/python_lib/bp_nn.py in sample(self, batch_size)
#     167             [batch_size, self.n])
#     168         for i in range(self.n):
# --> 169             x_hat = self.forward(sample)
#     170             #print(x_hat)
#     171             sample[:, i] = torch.bernoulli(
#
# ~/git/pytorch_test/python_lib/bp_nn.py in forward(self, x)
#     114     def forward(self, x):
#     115         x = x.view(x.shape[0], -1)
# --> 116         x_hat = self.net(x)
#     117
#     118         if self.x_hat_clip:
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#      90     def forward(self, input):
#      91         for module in self._modules.values():
# ---> 92             input = module(input)
#      93         return input
#      94
#
# /usr/local/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     545             result = self._slow_forward(*input, **kwargs)
#     546         else:
# --> 547             result = self.forward(*input, **kwargs)
#     548         for hook in self._forward_hooks.values():
#     549             hook_result = hook(self, input, result)
#
# ~/git/pytorch_test/python_lib/bp_nn.py in forward(self, x)
#      31
#      32     def forward(self, x):
# ---> 33         return nn.functional.linear(x, self.mask * self.weight, self.bias)
#      34
#      35 class myLayer_rand(nn.Linear):
#
# /usr/local/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1367     if input.dim() == 2 and bias is not None:
#    1368         # fused op is marginally faster
# -> 1369         ret = torch.addmm(bias, input, weight.t())
#    1370     else:
#    1371         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
res_nn_z2 = solvers.nn_sol(tree, betas_fast, max_step=1000,
                           bias = True, z2 = True, x_hat_clip = False)
res_nn_z2["name"]="nn_z2"
# Out:
# fe: -7.032 std_fe: 2.05E-02 M: 0.008 S: 0.683 E: -0.207: 0.0247, B1 = 0.040
# fe: -3.677 std_fe: 3.25E-02 M: 0.006 S: 0.645 E: -0.453: 0.0269, B1 = 0.230
# fe: -2.660 std_fe: 3.65E-02 M: 0.008 S: 0.549 E: -0.830: 0.0264, B1 = 0.768
# fe: -2.272 std_fe: 2.90E-02 M: 0.005 S: 0.356 E: -1.382: 0.0143, B1 = 1.823
# fe: -2.137 std_fe: 1.55E-02 M: 0.004 S: 0.189 E: -1.758: 0.0367, B1 = 3.159
# fe: -2.089 std_fe: 7.20E-03 M: 0.004 S: 0.107 E: -1.911: 0.0549, B1 = 4.320
# fe: -2.068 std_fe: 1.74E-03 M: 0.001 S: 0.072 E: -1.965: 0.0367, B1 = 5.303
# fe: -2.056 std_fe: 9.26E-04 M: 0.016 S: 0.057 E: -1.985: 0.042, B1 = 6.2117
# fe: -2.049 std_fe: 3.30E-04 M: 0.022 S: 0.050 E: -1.993 0.0178, B1 = 7.04973
# fe: -2.044 std_fe: 1.85E-03 M: 0.013 S: 0.046 E: -1.9970.0339, B1 = 7.46151
# fe: -2.040 std_fe: 1.34E-03 M: 0.007 S: 0.045 E: -1.9990.036, B1 = 7.915102
# fe: -2.036 std_fe: 2.67E-03 M: 0.012 S: 0.045 E: -1.9990.058, B1 = 8.03843
# fe: -2.033 std_fe: 4.74E-03 M: 0.010 S: 0.045 E: -1.9990.032, B1 = 8.14543
# fe: -2.031 std_fe: 5.02E-03 M: 0.006 S: 0.045 E: -1.9990.006, B1 = 8.25238
# fe: -2.029 std_fe: 5.44E-03 M: 0.004 S: 0.044 E: -1.999.068, B1 = 8.2637
# fe: -2.027 std_fe: 8.11E-03 M: 0.004 S: 0.045 E: -1.999.006, B1 = 8.2633
# fe: -2.025 std_fe: 6.13E-03 M: 0.003 S: 0.044 E: -1.999.066, B1 = 8.2850
# fe: -2.024 std_fe: 8.33E-03 M: 0.000 S: 0.045 E: -1.999.032, B1 = 8.2983
# fe: -2.022 std_fe: 1.09E-02 M: 0.010 S: 0.045 E: -1.9990.058, B1 = 8.3440
# fe: -2.021 std_fe: 9.44E-03 M: 0.011 S: 0.045 E: -1.9990.026, B1 = 8.42505

# %%
import bp_solver
imp.reload(bp_solver)
import solvers
imp.reload(solvers)
res_bp = solvers.bp_sol(tree, betas_fast, val_rand=0.1)
res_bp["name"]="bp"
# Out:
# fe: -7.031, ener: -0.199, M: 0.000, iter 7
# fe: -3.664, ener: -0.395, M: 0.000, iter 13
# fe: -2.606, ener: -0.583, M: 0.000, iter 47
# fe: -2.165, ener: -1.315, M: 0.736, iter 37
# fe: -2.050, ener: -1.768, M: 0.929, iter 13
# fe: -2.017, ener: -1.912, M: 0.975, iter 9
# fe: -2.006, ener: -1.964, M: 0.990, iter 7
# fe: -2.002, ener: -1.985, M: 0.996, iter 6
# fe: -2.001, ener: -1.994, M: 0.998, iter 6
# fe: -2.000, ener: -1.997, M: 0.999, iter 5
# fe: -2.000, ener: -1.999, M: 1.000, iter 5
# fe: -2.000, ener: -1.999, M: 1.000, iter 5
# fe: -2.000, ener: -2.000, M: 1.000, iter 4
# fe: -2.000, ener: -2.000, M: 1.000, iter 4
# fe: -2.000, ener: -2.000, M: 1.000, iter 4
# fe: -2.000, ener: -2.000, M: 1.000, iter 4
# fe: -2.000, ener: -2.000, M: 1.000, iter 4
# fe: -2.000, ener: -2.000, M: 1.000, iter 3
# fe: -2.000, ener: -2.000, M: 1.000, iter 3
# fe: -2.000, ener: -2.000, M: 1.000, iter 3

# %%
# %matplotlib inline
import imp
imp.reload(solvers)
label="fe"
plt= solvers.plot_quantity(label, res_ex, [res_bp, res_nn], init_=0)
#plt.ylim(-0.001,0.11)
plt.show()

# %%
# %matplotlib inline
label="M"
plt= solvers.plot_quantity(label, res_ex, [res_bp, res_nn])
plt.show()

# %%
# %matplotlib inline
label="M_i"
plt= solvers.plot_quantity_sum(label, res_ex, [res_bp, res_nn], init_=0)
plt.show()

# %%
import solvers
imp.reload(solvers)
plt = solvers.plot_all_corr(betas_fast[0:6], res_ex, [res_bp, res_nn], J_interaction)
plt.show()
