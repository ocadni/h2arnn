# %%
import numba
import sys
sys.path.insert(0, './python_lib')
import networkx as nx
import numpy as np
import graph_gen
import model
import random
from collections import defaultdict
import torch
import math

# %%
# %matplotlib inline

# %%
Degree = 3 # degree
Height = 4 # Height of the tree

# %%
N, J_interaction = graph_gen.tree_interaction(Degree,Height)

# %%
import graph_gen
import imp
imp.reload(graph_gen)
j = graph_gen.fixed_value(1)
J = graph_gen.set_J(J_interaction, j)
h = 0.00
H = np.full((N,), h)

# %%
import model
import imp
imp.reload(model)

tree = model.model(N, H, J, J_interaction)

# %%
F_exact = tree.exact()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-82-06cd4b7d939b> in <module>
# ----> 1 F_exact = tree.exact()
#
# ~/git/pytorch_test/python_lib/model.py in exact(self)
#      22
#      23     def exact(self):
# ---> 24         assert self.N < 28
#      25         J = torch.from_numpy(self.J).cpu().to(torch.float64)
#      26         H = torch.from_numpy(self.H).cpu().to(torch.float64)
#
# AssertionError:

# %%
import bp_solver
imp.reload(bp_solver)
from bp_solver import BP_solver

# %%
BP_tree = BP_solver(tree) 
BP_tree.converge()
# Out:
# ... -0.7453645360103194
#  iter:1,  err: 17.749 free_energy -1.22... -0.7321390309598247
#  iter:2,  err: 10.329 free_energy -1.13... -0.7375898662130472
#  iter:3,  err: 5.311 free_energy -1.11... -0.7370266025378371
#  iter:4,  err: 3.329 free_energy -1.11... -0.7370266025378371
#  iter:5,  err: 0.733 free_energy -1.11... -0.7370266025378371
#  iter:6,  err: 0.000 free_energy -1.11... -0.7370266025378371
#
# end
# tot_iter: 6,  error: 0.000 free_energy: -1.11
# Energy: -0.737
# M: 0.0
# S: 0.376
