# %%
import numba
import sys
sys.path.insert(0, './python_lib')
import networkx as nx
import numpy as np
import graph_gen
import model
import random
from collections import defaultdict
import torch
import math

# %%
# %matplotlib inline

# %%
Degree = 3 # degree
Height = 3 # Height of the tree

# %%
N, J_interaction = graph_gen.tree_interaction(d,h)

# %%
import graph_gen
import imp
imp.reload(graph_gen)
j = graph_gen.fixed_value(2)
J = graph_gen.set_J(J_interaction, j)
h = 1.
H = np.full((N,), h)

# %%
import model
import imp
imp.reload(model)

tree = model.model(N, H, J, J_interaction)

# %%
F_exact = tree.exact_numba()
# Out:
# Enumerating...
# 32000 / 32768(97.66%), E = 3.0, Z = 7.93e+14, F = -34.3
# Energy: -2.86
# M: 0.997
# S: 0.00945
# Free_energy: -2.868 (-2.868)

# %%
import bp_solver
imp.reload(bp_solver)
from bp_solver import BP_solver

# %%
BP_tree = BP_solver(tree) 
BP_tree.converge()
# Out:
# ... -2.696793461737973
#  iter:1,  err: 11.260 free_energy -2.82... -2.8517723281991576
#  iter:2,  err: 1.798 free_energy -2.87... -2.858508634903863
#  iter:3,  err: 0.156 free_energy -2.87... -2.8585591971205337
#  iter:4,  err: 0.003 free_energy -2.87... -2.8585591971205337
#  iter:5,  err: 0.000 free_energy -2.87... -2.8585591971205337
#
# end
# tot_iter: 5,  error: 0.000 free_energy: -2.87
# Energy: -2.86
# M: 0.997
# S: 0.00945
